# %% [markdown]
# # Students Performance Exploratory Data Analysis

# %% [markdown]
# In this session, I will use various methods of exploratory data analysis to examine the characteristics of the "Students Performance in Exams" dataset.
#
# The data contains eight variables used to explore the effect of various factors on test scores. The variables are:
#
# Gender - male or female
# Race/Ethnicity - split into 5 Groups (A, B, C, D, E)
# Parent Education Level - a student's parent's highest level of education
# Lunch - whether a student is in the standard or free/reduced lunch program
# Test Prep Course - whether or not a student completed the test preparation course
# Math Score
# Reading Score
# Writing Score
# Note: this is a fictional dataset used strictly for to demonstrate beginner data analysis skills. The results are not official and should not be used to conclude actual relationships between the variables listed and education.

# %% [markdown]
# ### Import necessary modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df.describe(include='all')
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
# mean       NaN            NaN                         NaN       NaN
# std        NaN            NaN                         NaN       NaN
# min        NaN            NaN                         NaN       NaN
# 25%        NaN            NaN                         NaN       NaN
# 50%        NaN            NaN                         NaN       NaN
# 75%        NaN            NaN                         NaN       NaN
# max        NaN            NaN                         NaN       NaN
#
#        test preparation course  math score  reading score  writing score
# count                     1000  1000.00000    1000.000000    1000.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
#To check if there are any missing values
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
#To check if there are any duplicates
df.duplicated().sum()
# Out:
# 0

# %%
#To view column names
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df['math score'].head()
# Out:
# 0    72
# 1    69
# 2    90
# 3    47
# 4    76
# Name: math score, dtype: int64

# %%
x=df['math score'].head()
type(x)
# Out:
# pandas.core.series.Series

# %%
df[['math score','reading score']].head()
# Out:
#    math score  reading score
# 0          72             72
# 1          69             90
# 2          90             95
# 3          47             57
# 4          76             78

# %%
#Unique values
df.gender.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
#Count of unique values
df.gender.nunique()
# Out:
# 2

# %%
df.rename(columns={'race/ethnicity':'race'},inplace=True)
df
# Out:
#      gender     race parental level of education         lunch  \
# 0    female  group B           bachelor's degree      standard
# 1    female  group C                some college      standard
# 2    female  group B             master's degree      standard
# 3      male  group A          associate's degree  free/reduced
# 4      male  group C                some college      standard
# ..      ...      ...                         ...           ...
# 995  female  group E             master's degree      standard
# 996    male  group C                 high school  free/reduced
# 997  female  group C                 high school  free/reduced
# 998  female  group D                some college      standard
# 999  female  group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# ...

# %%
df['race'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
df['race'].value_counts()
# Out:
# race
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
df['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
#Creating a new column from existing columns
df['avg score']=(df['math score']+df['reading score']+df['writing score'])/3
df
# Out:
#      gender     race parental level of education         lunch  \
# 0    female  group B           bachelor's degree      standard
# 1    female  group C                some college      standard
# 2    female  group B             master's degree      standard
# 3      male  group A          associate's degree  free/reduced
# 4      male  group C                some college      standard
# ..      ...      ...                         ...           ...
# 995  female  group E             master's degree      standard
# 996    male  group C                 high school  free/reduced
# 997  female  group C                 high school  free/reduced
# 998  female  group D                some college      standard
# 999  female  group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# ...

# %%
#round 
df['avg score']=round((df['math score']+df['reading score']+df['writing score'])/3,2)
df
# Out:
#      gender     race parental level of education         lunch  \
# 0    female  group B           bachelor's degree      standard
# 1    female  group C                some college      standard
# 2    female  group B             master's degree      standard
# 3      male  group A          associate's degree  free/reduced
# 4      male  group C                some college      standard
# ..      ...      ...                         ...           ...
# 995  female  group E             master's degree      standard
# 996    male  group C                 high school  free/reduced
# 997  female  group C                 high school  free/reduced
# 998  female  group D                some college      standard
# 999  female  group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# ...

# %%
df['avg score'].apply(np.ceil)
df
# Out:
#      gender     race parental level of education         lunch  \
# 0    female  group B           bachelor's degree      standard
# 1    female  group C                some college      standard
# 2    female  group B             master's degree      standard
# 3      male  group A          associate's degree  free/reduced
# 4      male  group C                some college      standard
# ..      ...      ...                         ...           ...
# 995  female  group E             master's degree      standard
# 996    male  group C                 high school  free/reduced
# 997  female  group C                 high school  free/reduced
# 998  female  group D                some college      standard
# 999  female  group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# ...

# %%
#Creating a new column
df['New col']=list(range(1000))
df
# Out:
#      gender     race parental level of education         lunch  \
# 0    female  group B           bachelor's degree      standard
# 1    female  group C                some college      standard
# 2    female  group B             master's degree      standard
# 3      male  group A          associate's degree  free/reduced
# 4      male  group C                some college      standard
# ..      ...      ...                         ...           ...
# 995  female  group E             master's degree      standard
# 996    male  group C                 high school  free/reduced
# 997  female  group C                 high school  free/reduced
# 998  female  group D                some college      standard
# 999  female  group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# ...

# %%
#drop 
df.drop(2)
# Out:
#      gender     race parental level of education         lunch  \
# 0    female  group B           bachelor's degree      standard
# 1    female  group C                some college      standard
# 3      male  group A          associate's degree  free/reduced
# 4      male  group C                some college      standard
# 5    female  group B          associate's degree      standard
# ..      ...      ...                         ...           ...
# 995  female  group E             master's degree      standard
# 996    male  group C                 high school  free/reduced
# 997  female  group C                 high school  free/reduced
# 998  female  group D                some college      standard
# 999  female  group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# ...

# %%
df
# Out:
#      gender     race parental level of education         lunch  \
# 0    female  group B           bachelor's degree      standard
# 1    female  group C                some college      standard
# 2    female  group B             master's degree      standard
# 3      male  group A          associate's degree  free/reduced
# 4      male  group C                some college      standard
# ..      ...      ...                         ...           ...
# 995  female  group E             master's degree      standard
# 996    male  group C                 high school  free/reduced
# 997  female  group C                 high school  free/reduced
# 998  female  group D                some college      standard
# 999  female  group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# ...

# %%
df.drop('avg score',axis=1,inplace=True)

# %%
df
# Out:
#      gender     race parental level of education         lunch  \
# 0    female  group B           bachelor's degree      standard
# 1    female  group C                some college      standard
# 2    female  group B             master's degree      standard
# 3      male  group A          associate's degree  free/reduced
# 4      male  group C                some college      standard
# ..      ...      ...                         ...           ...
# 995  female  group E             master's degree      standard
# 996    male  group C                 high school  free/reduced
# 997  female  group C                 high school  free/reduced
# 998  female  group D                some college      standard
# 999  female  group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  New col
# 0                      none          72             72             74        0
# ...

# %%
#Dropping multiple columns
df.drop(['math score','reading score'],axis=1)
# Out:
#      gender     race parental level of education         lunch  \
# 0    female  group B           bachelor's degree      standard
# 1    female  group C                some college      standard
# 2    female  group B             master's degree      standard
# 3      male  group A          associate's degree  free/reduced
# 4      male  group C                some college      standard
# ..      ...      ...                         ...           ...
# 995  female  group E             master's degree      standard
# 996    male  group C                 high school  free/reduced
# 997  female  group C                 high school  free/reduced
# 998  female  group D                some college      standard
# 999  female  group D                some college  free/reduced
#
#     test preparation course  writing score  New col
# 0                      none             74        0
# 1                 completed             88        1
# ...

# %% [markdown]
# ## How to write query?

# %%
df['math score']>70
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999     True
# Name: math score, Length: 1000, dtype: bool

# %%
df[df['math score']>70]
# Out:
#      gender     race parental level of education         lunch  \
# 0    female  group B           bachelor's degree      standard
# 2    female  group B             master's degree      standard
# 4      male  group C                some college      standard
# 5    female  group B          associate's degree      standard
# 6    female  group B                some college      standard
# ..      ...      ...                         ...           ...
# 984  female  group C            some high school      standard
# 987    male  group E            some high school      standard
# 990    male  group E                 high school  free/reduced
# 995  female  group E             master's degree      standard
# 999  female  group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  New col
# 0                      none          72             72             74        0
# ...

# %%
#To retrieve students details who completed test preparation course
df[df['test preparation course']=='completed']
# Out:
#      gender     race parental level of education         lunch  \
# 1    female  group C                some college      standard
# 6    female  group B                some college      standard
# 8      male  group D                 high school  free/reduced
# 13     male  group A                some college      standard
# 18     male  group C             master's degree  free/reduced
# ..      ...      ...                         ...           ...
# 990    male  group E                 high school  free/reduced
# 991  female  group B            some high school      standard
# 995  female  group E             master's degree      standard
# 997  female  group C                 high school  free/reduced
# 998  female  group D                some college      standard
#
#     test preparation course  math score  reading score  writing score  New col
# 1                 completed          69             90             88        1
# ...

# %%
#math score>70 and test preparation completed students
df[(df['math score']>70)&(df['test preparation course']=='completed')]
# Out:
#      gender     race parental level of education         lunch  \
# 6    female  group B                some college      standard
# 13     male  group A                some college      standard
# 24     male  group D           bachelor's degree  free/reduced
# 35     male  group E          associate's degree      standard
# 38   female  group D          associate's degree  free/reduced
# ..      ...      ...                         ...           ...
# 982    male  group B            some high school      standard
# 983  female  group A                some college      standard
# 987    male  group E            some high school      standard
# 990    male  group E                 high school  free/reduced
# 995  female  group E             master's degree      standard
#
#     test preparation course  math score  reading score  writing score  New col
# 6                 completed          88             95             92        6
# ...

# %%
#Parental education='high school' or 'some high school' and test preparation='completed'
df[((df['parental level of education']=='high school')|(df['parental level of education']=='some high school'))&(df['test preparation course']=='completed')]
# Out:
#      gender     race parental level of education         lunch  \
# 8      male  group D                 high school  free/reduced
# 49     male  group C                 high school      standard
# 54   female  group C            some high school  free/reduced
# 78   female  group D            some high school      standard
# 96     male  group B            some high school      standard
# ..      ...      ...                         ...           ...
# 982    male  group B            some high school      standard
# 987    male  group E            some high school      standard
# 990    male  group E                 high school  free/reduced
# 991  female  group B            some high school      standard
# 997  female  group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  New col
# 8                 completed          64             64             67        8
# ...

# %%
#Parental education='high school' or 'some high school' and test preparation='completed'
df[(df['parental level of education'].isin(['high school', 'some high school'])) & (df['test preparation course'] == 'completed')]
# Out:
#      gender     race parental level of education         lunch  \
# 8      male  group D                 high school  free/reduced
# 49     male  group C                 high school      standard
# 54   female  group C            some high school  free/reduced
# 78   female  group D            some high school      standard
# 96     male  group B            some high school      standard
# ..      ...      ...                         ...           ...
# 982    male  group B            some high school      standard
# 987    male  group E            some high school      standard
# 990    male  group E                 high school  free/reduced
# 991  female  group B            some high school      standard
# 997  female  group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  New col
# 8                 completed          64             64             67        8
# ...

# %% [markdown]
# ## Slicing in DF
# DFname.loc[RowName,ColName]
#
# DFname.iloc[RowIndex,ColIndex]

# %%
df.loc[(2,3,4),('race','parental level of education')]
# Out:
#       race parental level of education
# 2  group B             master's degree
# 3  group A          associate's degree
# 4  group C                some college

# %%
df.loc[:,('race','parental level of education')] #All rows
# Out:
#         race parental level of education
# 0    group B           bachelor's degree
# 1    group C                some college
# 2    group B             master's degree
# 3    group A          associate's degree
# 4    group C                some college
# ..       ...                         ...
# 995  group E             master's degree
# 996  group C                 high school
# 997  group C                 high school
# 998  group D                some college
# 999  group D                some college
#
# [1000 rows x 2 columns]

# %%
df.loc[(2,3,4),:] #All columns
# Out:
#    gender     race parental level of education         lunch  \
# 2  female  group B             master's degree      standard
# 3    male  group A          associate's degree  free/reduced
# 4    male  group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  New col
# 2                    none          90             95             93        2
# 3                    none          47             57             44        3
# 4                    none          76             78             75        4

# %%
df.iloc[[2,3,4],[0,1]] #access using iloc
# Out:
#    gender     race
# 2  female  group B
# 3    male  group A
# 4    male  group C

# %% [markdown]
# ## Pair plot

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='gender')

# %%
sns.pairplot(df,hue='gender',diag_kind='hist')

# %% [markdown]
# # Count Plot
# Distribution of data among categorical variable

# %%
sns.countplot(x='gender',data=df,palette='viridis')
plt.ylabel('Gender count')
# Out:
# Text(0, 0.5, 'Gender count')

# %%
sns.countplot(x='race',data=df,palette='viridis')
# Out:
# <Axes: xlabel='race', ylabel='count'>

# %% [markdown]
# # Bar Plot

# %%
#To set overall visual style of the plots
sns.set_style('darkgrid')

# %%
#Finding category count using bar plot
c=df['gender'].value_counts()
c
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
plt.bar(c.index,c.values)
# Out:
# <BarContainer object of 2 artists>

# %%
r=df['race'].value_counts()
r
# Out:
# race
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
plt.bar(r.index,r.values)
# Out:
# <BarContainer object of 5 artists>

# %%
#parental level of education - Count
plt.figure(figsize=(12,6))
sns.countplot(x='parental level of education',data=df,palette='rocket')
# Out:
# <Axes: xlabel='parental level of education', ylabel='count'>

# %% [markdown]
# # Box Plot
# To view the distribution of various test scores among each categorical variables

# %%
sns.boxplot(x='gender',y='math score',data=df)
# Out:
# <Axes: xlabel='gender', ylabel='math score'>

# %%
sns.boxplot(x='gender',y='reading score',data=df)
# Out:
# <Axes: xlabel='gender', ylabel='reading score'>

# %%
sns.boxplot(x='gender',y='writing score',data=df)
# Out:
# <Axes: xlabel='gender', ylabel='writing score'>

# %% [markdown]
# #Data story :
# From the box plots based on gender, males score more in maths while females score more in reading and writing

# %% [markdown]
# ### Analysing race categories scores

# %%
sns.boxplot(x='race',y='math score',data=df)
# Out:
# <Axes: xlabel='race', ylabel='math score'>

# %%
sns.boxplot(x='race',y='reading score',data=df)
# Out:
# <Axes: xlabel='race', ylabel='reading score'>

# %%
sns.boxplot(x='race',y='writing score',data=df)
# Out:
# <Axes: xlabel='race', ylabel='writing score'>

# %% [markdown]
# To find the students who passed or failed in maths, based on pass rate if pass rate is 60.

# %%
pass_rate=60

# %%
df['math pass_rate']=np.where(df['math score']<pass_rate,'Fail','Pass')
df
# Out:
#      gender     race parental level of education         lunch  \
# 0    female  group B           bachelor's degree      standard
# 1    female  group C                some college      standard
# 2    female  group B             master's degree      standard
# 3      male  group A          associate's degree  free/reduced
# 4      male  group C                some college      standard
# ..      ...      ...                         ...           ...
# 995  female  group E             master's degree      standard
# 996    male  group C                 high school  free/reduced
# 997  female  group C                 high school  free/reduced
# 998  female  group D                some college      standard
# 999  female  group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# ...

# %%
#To find the no. of students who passed/failed
df['math pass_rate'].value_counts()
# Out:
# math pass_rate
# Pass    677
# Fail    323
# Name: count, dtype: int64

# %%
df['reading pass_rate']=np.where(df['reading score']<pass_rate,'Fail','Pass')
df
# Out:
#      gender     race parental level of education         lunch  \
# 0    female  group B           bachelor's degree      standard
# 1    female  group C                some college      standard
# 2    female  group B             master's degree      standard
# 3      male  group A          associate's degree  free/reduced
# 4      male  group C                some college      standard
# ..      ...      ...                         ...           ...
# 995  female  group E             master's degree      standard
# 996    male  group C                 high school  free/reduced
# 997  female  group C                 high school  free/reduced
# 998  female  group D                some college      standard
# 999  female  group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# ...

# %%
df['reading pass_rate'].value_counts()
# Out:
# reading pass_rate
# Pass    746
# Fail    254
# Name: count, dtype: int64

# %%
df['writing pass_rate']=np.where(df['writing score']<pass_rate,'Fail','Pass')
df
# Out:
#      gender     race parental level of education         lunch  \
# 0    female  group B           bachelor's degree      standard
# 1    female  group C                some college      standard
# 2    female  group B             master's degree      standard
# 3      male  group A          associate's degree  free/reduced
# 4      male  group C                some college      standard
# ..      ...      ...                         ...           ...
# 995  female  group E             master's degree      standard
# 996    male  group C                 high school  free/reduced
# 997  female  group C                 high school  free/reduced
# 998  female  group D                some college      standard
# 999  female  group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# ...

# %%
df['writing pass_rate'].value_counts()
# Out:
# writing pass_rate
# Pass    719
# Fail    281
# Name: count, dtype: int64

# %% [markdown]
# #### astype - To change the data type of a column

# %%
df['math pass_rate'].astype(str)
# Out:
# 0      Pass
# 1      Pass
# 2      Pass
# 3      Fail
# 4      Pass
#        ...
# 995    Pass
# 996    Pass
# 997    Fail
# 998    Pass
# 999    Pass
# Name: math pass_rate, Length: 1000, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race                         1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
#  8   New col                      1000 non-null   int64
#  9   math pass_rate               1000 non-null   object
#  10  reading pass_rate            1000 non-null   object
#  11  writing pass_rate            1000 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 93.9+ KB

# %%
df['math score'].astype(np.int32)
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int32

# %%
df['math score'].dtype
# Out:
# dtype('int64')

# %%
df['math score']=df['math score'].astype(np.int32)
df['math score'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# From the columns created, a frequency table can be created to show the pass rate for each grouping. Below is the pass rate table and count plot for males and females on the math exam:

# %%
math_table = pd.crosstab(index = df['gender'], columns = df['math pass_rate'])
math_table['PercentPass'] = round(math_table['Pass'] / (math_table['Pass'] + math_table['Fail'])*100,2)
math_table
# Out:
# math pass_rate  Fail  Pass  PercentPass
# gender
# female           197   321        61.97
# male             126   356        73.86

# %%
plt.figure(figsize = (10,5))
sns.countplot(x = 'gender', data = df, hue = 'math pass_rate', palette = 'viridis')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %% [markdown]
# Below is the pass rate table and countplot for males and females on the reading exam:

# %%
reading_table = pd.crosstab(index = df['gender'], columns = df['reading pass_rate'])
reading_table['PercentPass'] = round(reading_table['Pass'] / (reading_table['Pass'] + reading_table['Fail'])*100,2)
reading_table
# Out:
# reading pass_rate  Fail  Pass  PercentPass
# gender
# female               91   427        82.43
# male                163   319        66.18

# %%
plt.figure(figsize = (10,5))
sns.countplot(x = 'gender', data = df, hue = 'reading pass_rate', palette = 'viridis')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %% [markdown]
# Below is the pass rate table and countplot for males and females on the writing exam:

# %%
writing_table = pd.crosstab(index = df['gender'], columns = df['writing pass_rate'])
writing_table['PercentPass'] = round(writing_table['Pass'] / (writing_table['Pass'] + writing_table['Fail'])*100,2)
writing_table
# Out:
# writing pass_rate  Fail  Pass  PercentPass
# gender
# female               94   424        81.85
# male                187   295        61.20

# %%
sns.countplot(x='gender',data=df,hue='writing pass_rate')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %% [markdown]
# From the information above, females passed the reading and writing exams more consistently than males. However, males passed the math exam more consistently than females.

# %% [markdown]
# Below are the pass rate tables and countplots for each exam based on race/ethnicity:

# %%
math_table_re = pd.crosstab(index = df['race'], columns = df['math pass_rate'])
math_table_re['PercentPass'] = round(math_table_re['Pass'] / (math_table_re['Pass'] + math_table_re['Fail'])*100,2)
math_table_re
# Out:
# math pass_rate  Fail  Pass  PercentPass
# race
# group A           42    47        52.81
# group B           71   119        62.63
# group C          113   206        64.58
# group D           72   190        72.52
# group E           25   115        82.14

# %%
plt.figure(figsize = (10,5))
sns.countplot(x = 'race', data = df, hue = 'math pass_rate', palette = 'mako')
# Out:
# <Axes: xlabel='race', ylabel='count'>

# %%
read_table_re = pd.crosstab(index = df['race'], columns = df['reading pass_rate'])
read_table_re['PercentPass'] = round(read_table_re['Pass'] / (read_table_re['Pass'] + read_table_re['Fail'])*100,2)
read_table_re
# Out:
# reading pass_rate  Fail  Pass  PercentPass
# race
# group A              35    54        60.67
# group B              55   135        71.05
# group C              75   244        76.49
# group D              62   200        76.34
# group E              27   113        80.71

# %%
sns.countplot(x='race',data=df,hue='reading pass_rate',palette='mako')
# Out:
# <Axes: xlabel='race', ylabel='count'>

# %%
write_table_re=pd.crosstab(index=df['race'],columns=df['writing pass_rate'])
write_table_re['PassPercent']=round(write_table_re['Pass']/(write_table_re['Pass'] + write_table_re['Fail'])*100,2)
write_table_re
# Out:
# writing pass_rate  Fail  Pass  PassPercent
# race
# group A              37    52        58.43
# group B              61   129        67.89
# group C              94   225        70.53
# group D              59   203        77.48
# group E              30   110        78.57

# %%
sns.countplot(x='race',data=df,hue='writing pass_rate',palette='mako')
# Out:
# <Axes: xlabel='race', ylabel='count'>

# %% [markdown]
# From the information above, group C had the highest pass percentage for each exam, while group A had the lowest pass percentage for each exam.
